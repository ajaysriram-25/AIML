# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaysriram-25/AIML/blob/main/Coursera_Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)   # Do not change this value: required to be compatible with solutions generated by the autograder.

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)   # Do not change this value: required to be compatible with solutions generated by the autograder.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score

def engagement_model():
    # Load the datasets
    train = pd.read_csv('assets/train.csv')
    test = pd.read_csv('assets/test.csv')

    # Separate target and features
    y_train = train['engagement']
    X_train = train.drop(['engagement'], axis=1)
    X_test = test.copy()

    # Ensure consistent feature sets
    missing_cols = set(X_train.columns) - set(X_test.columns)
    for col in missing_cols:
        X_test[col] = 0  # Add missing columns with default values

    extra_cols = set(X_test.columns) - set(X_train.columns)
    X_test = X_test.drop(extra_cols, axis=1)  # Drop extra columns from test set

    # Confirm consistent feature count
    assert X_train.shape[1] == X_test.shape[1], "Feature count mismatch between train and test sets."

    # Optional: Split training data for validation
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

    # Train Gradient Boosting Classifier
    clf = GradientBoostingClassifier(random_state=42)
    clf.fit(X_train, y_train)

    # Evaluate on validation set (optional)
    val_probs = clf.predict_proba(X_val)[:, 1]
    auc_score = roc_auc_score(y_val, val_probs)
    print(f"Validation AUC: {auc_score:.4f}")

    # Predict probabilities on the test set
    test_probs = clf.predict_proba(X_test)[:, 1]

    # Return a Pandas Series with probabilities
    result = pd.Series(test_probs, index=test['id'], name='engagement')
    return result

# Call the function and save the result
engagement_predictions = engagement_model()
print(engagement_predictions.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-120a52fe2a8c> in <cell line: 0>()
#      45
#      46 # Call the function and save the result
# ---> 47 engagement_predictions = engagement_model()
#      48 print(engagement_predictions.head())
#
# <ipython-input-3-120a52fe2a8c> in engagement_model()
#       6 def engagement_model():
#       7     # Load the datasets
# ----> 8     train = pd.read_csv('assets/train.csv')
#       9     test = pd.read_csv('assets/test.csv')
#      10
#
# ...

# %%
stu_ans = engagement_model()
assert isinstance(stu_ans, pd.Series), "Your function should return a pd.Series. "
assert len(stu_ans) == 2309, "Your series is of incorrect length: expected 2309 "
assert np.issubdtype(stu_ans.index.dtype, np.integer), "Your answer pd.Series should have an index of integer type representing video id."
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-9a31084446ea> in <cell line: 0>()
# ----> 1 stu_ans = engagement_model()
#       2 assert isinstance(stu_ans, pd.Series), "Your function should return a pd.Series. "
#       3 assert len(stu_ans) == 2309, "Your series is of incorrect length: expected 2309 "
#       4 assert np.issubdtype(stu_ans.index.dtype, np.integer), "Your answer pd.Series should have an index of integer type representing video id."
#
# <ipython-input-3-120a52fe2a8c> in engagement_model()
#       6 def engagement_model():
#       7     # Load the datasets
# ----> 8     train = pd.read_csv('assets/train.csv')
#       9     test = pd.read_csv('assets/test.csv')
#      10
#
# ...

# %%
import numpy as np
import pandas as pd  # Also ensure pandas is imported
import numpy as np
import pandas as pd

stu_ans = engagement_model()

assert isinstance(stu_ans, pd.Series), "Your function should return a pd.Series."
assert len(stu_ans) == 2309, "Your series is of incorrect length: expected 2309"
assert np.issubdtype(stu_ans.index.dtype, np.integer), "Your answer pd.Series should have an index of integer type representing video id."
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-d51f7b791512> in <cell line: 0>()
#       4 import pandas as pd
#       5
# ----> 6 stu_ans = engagement_model()
#       7
#       8 assert isinstance(stu_ans, pd.Series), "Your function should return a pd.Series."
#
# <ipython-input-3-120a52fe2a8c> in engagement_model()
#       6 def engagement_model():
#       7     # Load the datasets
# ----> 8     train = pd.read_csv('assets/train.csv')
#       9     test = pd.read_csv('assets/test.csv')
#      10
#
# ...

# %%
df_train = pd.read_csv('./assets/train.csv')
print(df_train.shape)
df_train.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-271858a52e62> in <cell line: 0>()
# ----> 1 df_train = pd.read_csv('./assets/train.csv')
#       2 print(df_train.shape)
#       3 df_train.head()
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, subaxes = plt.subplots(int(len(df_train.columns[1:-1]) / 3) + 1, 3, figsize=(15, 15))

ii = 1
for row in subaxes:
    for this_axis in row:
        col = df_train.columns[ii]
        if df_train[col].dtype == 'bool':  # Skip boolean columns
            continue
        sns.histplot(df_train.iloc[:, ii], ax=this_axis)
        this_axis.set_title('{}'.format(col))
        ii += 1
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-efb47e6f698a> in <cell line: 0>()
#       2 import seaborn as sns
#       3
# ----> 4 fig, subaxes = plt.subplots(int(len(df_train.columns[1:-1]) / 3) + 1, 3, figsize=(15, 15))
#       5
#       6 ii = 1
#
# NameError: name 'df_train' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, subaxes = plt.subplots(int(len(df_train.columns[1:-1]) / 3) + 1, 3, figsize=(15, 15))

ii = 1
for row in subaxes:
    for this_axis in row:
        col = df_train.columns[ii]
        if df_train[col].dtype == 'bool':  # Skip boolean columns
            continue
        sns.histplot(df_train.iloc[:, ii], ax=this_axis)
        this_axis.set_title('{}'.format(col))
        ii += 1
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-efb47e6f698a> in <cell line: 0>()
#       2 import seaborn as sns
#       3
# ----> 4 fig, subaxes = plt.subplots(int(len(df_train.columns[1:-1]) / 3) + 1, 3, figsize=(15, 15))
#       5
#       6 ii = 1
#
# NameError: name 'df_train' is not defined

# %%
df_corr = df_train.iloc[:,1:].corr()
df_corr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8e1008a0b260> in <cell line: 0>()
# ----> 1 df_corr = df_train.iloc[:,1:].corr()
#       2 df_corr
#
# NameError: name 'df_train' is not defined

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df_corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 7},
           xticklabels= df_corr.columns,
           yticklabels= df_corr.columns,
           cmap=sns.diverging_palette(120, 10, as_cmap=True))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bfb638a45dea> in <cell line: 0>()
#       1 plt.figure(figsize=(8,8))
# ----> 2 sns.heatmap(df_corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 7},
#       3            xticklabels= df_corr.columns,
#       4            yticklabels= df_corr.columns,
#       5            cmap=sns.diverging_palette(120, 10, as_cmap=True))
#
# NameError: name 'df_corr' is not defined

# %%
from sklearn.feature_selection import SelectKBest, f_classif

X = df_train.iloc[:,1:-1]
y = df_train.iloc[:,-1]

this_k = 8
selector = SelectKBest(f_classif, k='all')
selector.fit(X, y)

# get the score for each feature
scores = selector.scores_

feature_scores = pd.DataFrame({'Feature': X.columns, 'Score': scores})
total = feature_scores['Score'].sum()
feature_scores['Score'] = feature_scores['Score']/total
feature_scores.sort_values('Score', ascending=False, inplace=True)

plt.figure(figsize=(6,3))
sns.barplot(x='Score', y='Feature', data=feature_scores)
plt.xlabel('Score')
plt.ylabel('Features')
plt.title('Features importance (Normalized)')
# plt.xticks(rotation=20, ha='right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-44f7ddb6119a> in <cell line: 0>()
#       1 from sklearn.feature_selection import SelectKBest, f_classif
#       2
# ----> 3 X = df_train.iloc[:,1:-1]
#       4 y = df_train.iloc[:,-1]
#       5
#
# NameError: name 'df_train' is not defined
